# %%
print("====== SALES KPI DASHBOARD ======")
print(f"Total Revenue   : ₹{df['Revenue'].sum():,}")
print(f"Total Units Sold: {df['Sales_Units'].sum()}")
print(f"Best Month      : {df.loc[df['Revenue'].idxmax(), 'Month']}")
print(f"Top Product     : {df.groupby('Product')['Revenue'].sum().idxmax()}")
# Out:
# ====== SALES KPI DASHBOARD ======
# Total Revenue   : ₹619,000
# Total Units Sold: 2150
# Best Month      : Oct
# Top Product     : Laptop

# %%
plt.figure(figsize=(10,4))
plt.plot(df['Month'], df['Revenue'], marker='o', color='steelblue', linewidth=2)
plt.title('Monthly Revenue Trend')
plt.xlabel('Month')
plt.ylabel('Revenue (₹)')
plt.grid(True)
plt.tight_layout()
plt.savefig('revenue_trend.png')
plt.show()

# %%
product_revenue = df.groupby('Product')['Revenue'].sum().reset_index()

plt.figure(figsize=(6,4))
sns.barplot(data=product_revenue, x='Product', y='Revenue', palette='Blues_d')
plt.title('Revenue by Product')
plt.ylabel('Total Revenue (₹)')
plt.tight_layout()
plt.savefig('product_revenue.png')
plt.show()
# Out:
# C:\Users\Sandhya\AppData\Local\Temp\ipykernel_12216\115052356.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=product_revenue, x='Product', y='Revenue', palette='Blues_d')

# %%
region_sales = df.groupby('Region')['Sales_Units'].sum().reset_index()

plt.figure(figsize=(6,4))
sns.barplot(data=region_sales, x='Region', y='Sales_Units', palette='Greens_d')
plt.title('Sales Units by Region')
plt.ylabel('Total Units Sold')
plt.tight_layout()
plt.savefig('region_sales.png')
plt.show()
# Out:
# C:\Users\Sandhya\AppData\Local\Temp\ipykernel_12216\414496282.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=region_sales, x='Region', y='Sales_Units', palette='Greens_d')

# %%
data = {
    'Month': ['Jan','Feb','Mar','Apr','May','Jun',
              'Jul','Aug','Sep','Oct','Nov','Dec'],
    'Product': ['Laptop','Phone','Tablet','Laptop','Phone','Tablet',
                'Laptop','Phone','Tablet','Laptop','Phone','Tablet'],
    'Sales_Units': [120,200,150,180,220,160,140,210,170,190,230,180],
    'Revenue':     [60000,40000,30000,90000,44000,32000,
                    70000,42000,34000,95000,46000,36000],
    'Region': ['North','South','East','West','North','South',
               'East','West','North','South','East','West']
}

df = pd.DataFrame(data)
print(df)
# Out:
#    Month Product  Sales_Units  Revenue Region
# 0    Jan  Laptop          120    60000  North
# 1    Feb   Phone          200    40000  South
# 2    Mar  Tablet          150    30000   East
# 3    Apr  Laptop          180    90000   West
# 4    May   Phone          220    44000  North
# 5    Jun  Tablet          160    32000  South
# 6    Jul  Laptop          140    70000   East
# 7    Aug   Phone          210    42000   West
# 8    Sep  Tablet          170    34000  North
# 9    Oct  Laptop          190    95000  South
# 10   Nov   Phone          230    46000   East
# 11   Dec  Tablet          180    36000   West

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
